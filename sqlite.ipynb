# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect("db.sqlite3")

# %%
pd.read_sql_query("SELECT * FROM users;", conn)

# %%
pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table';", conn)
# Out:
#                           name
# 0            django_migrations
# 1              sqlite_sequence
# 2       auth_group_permissions
# 3             auth_user_groups
# 4   auth_user_user_permissions
# 5         accounts_userprofile
# 6             django_admin_log
# 7          django_content_type
# 8              auth_permission
# 9                   auth_group
# 10                   auth_user
# 11            listings_listing
# 12              django_session

# %%
pd.read_sql_query("SELECT * FROM auth_user;", conn)
# Out:
#    id                                           password  \
# 0   1  pbkdf2_sha256$720000$T6dqqGDWyXdQi0M20qyE9p$oZ...
# 1   2  pbkdf2_sha256$720000$cwH4kqM7K5kPeeswlgTkko$wz...
# 2   3  pbkdf2_sha256$720000$GNxilPPFMVat6IuI8LKUqn$a+...
# 3   4  pbkdf2_sha256$720000$BIzM0hRPJDBQsY9s2umYeC$lA...
#
#                    last_login  is_superuser            username last_name  \
# 0  2024-07-21 11:04:44.578065             0  sadanobu.mizusako2
# 1  2024-07-21 11:04:55.488719             0  sadanobu.mizusako3
# 2  2024-07-21 11:14:16.675322             0  sadanobu.mizusako4
# 3  2024-07-21 11:14:26.811237             0  sadanobu.mizusako5        bb
#
#        email  is_staff  is_active                 date_joined first_name
# 0                    0          1  2024-07-21 10:40:38.211454
# 1                    0          1  2024-07-21 10:46:37.282089
# 2                    0          1  2024-07-21 11:05:15.196195
# 3  aa@aa.com         0          1  2024-07-21 11:13:31.002164         aa

# %%
pd.read_sql_query("SELECT * FROM accounts_userprofile;", conn)
# Out:
#    id user_type  is_owner  user_id
# 0   1     owner         0        1
# 1   2     guest         0        2
# 2   3     owner         0        3
# 3   4                   0        4
